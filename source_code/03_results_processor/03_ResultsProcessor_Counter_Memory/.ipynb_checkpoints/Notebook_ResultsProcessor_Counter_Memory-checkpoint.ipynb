# %%
import os
import gzip
import pickle

# %%
stations = {}
with open("../../01_coordinates/coordinates.csv", "r") as f:
    first_line = True
    for line in f.readlines():
        if first_line:
            first_line = False
        else:
            id, latitude, longitude = (line.replace("\n", "").split(","))
            stations[id] = {}
            stations[id]["coordinates"] = [latitude, longitude]

# %%
import threading
import queue
with gzip.GzipFile("./ResultsProcessor_Counter_Memory_Results", "rb") as f:
    places_near_ev = pickle.load(f)

# %%
len(places_near_ev.keys())
# Out:
# 434503

# %%
places_near_ev[list(places_near_ev.keys())[0]]
# Out:
# [(42.349411867105665, -71.04131949626962)]

# %%
processed_places_near_ev = {}
for key in places_near_ev:
    processed_places_near_ev[places_near_ev[key]] = len(places_near_ev[key])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 processed_places_near_ev = {}
#       2 for key in places_near_ev:
# ----> 3     processed_places_near_ev[places_near_ev[key]["name"]] = len(places_near_ev[key]["coordinates"])
#
# TypeError: list indices must be integers or slices, not str

# %%
processed_places_near_ev = dict(sorted(processed_places_near_ev.items(), key=lambda item: item[1], reverse=True))

# %%
processed_places_near_ev
# Out:
# {'Starbucks': 6173,
#  'Subway': 4319,
#  "McDonald's": 3113,
#  "Dunkin'": 2466,
#  'CVS Pharmacy': 2201,
#  'T-Mobile': 1908,
#  '7-Eleven': 1846,
#  'Walgreens': 1699,
#  'Burger King': 1638,
#  'AT&T Store': 1632,
#  'Taco Bell': 1601,
#  'Chipotle Mexican Grill': 1489,
#  "Wendy's": 1486,
#  'Dominos Pizza': 1108,
#  'Chick-fil-A': 1037,
#  'Panda Express': 972,
#  'Great Clips': 930,
#  'Panera Bread': 903,
#  "Jimmy John's": 892,
#  'Dollar Tree': 872,
#  'Pizza Hut': 822,
#  "Jersey Mike's Subs": 821,
#  'KFC': 805,
#  'Target': 796,
#  'Bath & Body Works': 743,
#  'Supercuts': 706,
#  "Arby's": 691,
#  'Walmart Supercenter': 677,
#  'Verizon': 667,
#  'Circle K': 662,
#  'Jack in the Box': 642,
#  'Five Guys': 595,
#  'Popeyes Louisiana Kitchen': 591,
#  'Papa Johns Pizza': 579,
#  'IHOP': 563,
#  'GNC': 560,
#  'Ulta Beauty': 548,
#  'Ross Dress for Less': 547,
#  'Sherwin-Williams Paint Store': 533,
#  "O'Reilly Auto Parts": 529,
#  'Rite Aid': 528,
#  'The Home Depot': 521,
#  "Denny's": 512,
#  'Sally Beauty Supply': 499,
#  'Wingstop': 495,
#  'Baskin-Robbins': 492,
#  'Jamba': 469,
#  'Michaels': 466,
#  'Sunglass Hut': 465,
#  "Applebee's Grill + Bar": 463,
#  'Buffalo Wild Wings': 452,
#  "Chili's": 451,
#  'Victra - Verizon Authorized Retailer': 442,
#  'Sonic Drive-In': 441,
#  'SEPHORA': 428,
#  'LensCrafters': 428,
#  'Cold Stone Creamery': 417,
#  'ALDI': 414,
#  'GameStop': 410,
#  "Auntie Anne's": 408,
#  "Kohl's": 408,
#  "Lowe's Home Improvement": 407,
#  'Little Caesars Pizza': 403,
#  "Carl's Jr": 401,
#  'Gamestop': 401,
#  'Old Navy': 401,
#  'Whole Foods Market': 372,
#  'Speedway': 368,
#  'TJ Maxx': 366,
#  'Safeway': 361,
#  'Marshalls': 356,
#  'Victorias Secret': 355,
#  'Tropical Smoothie Cafe': 350,
#  'Dollar General': 350,
#  'Olive Garden Italian Restaurant': 339,
#  'Five Below': 336,
#  'Kay Jewelers': 332,
#  'Foot Locker': 328,
#  'Smoothie King': 326,
#  'Firehouse Subs': 317,
#  'Vans': 316,
#  'Edible Arrangements': 308,
#  "Men's Wearhouse": 307,
#  'Hot Topic': 306,
#  "Trader Joe's": 301,
#  "DICK'S Sporting Goods": 300,
#  'Life Storage': 291,
#  'Cricket': 290,
#  "Macy's": 289,
#  'American Eagle Outfitters': 288,
#  'Dairy Queen Grill & Chill': 286,
#  'H&M': 285,
#  'Pure Barre': 275,
#  'QDOBA Mexican Eats': 275,
#  'The Vitamin Shoppe': 273,
#  'U-Haul Neighborhood Dealer': 273,
#  'Famous Footwear': 268,
#  'Bed Bath & Beyond': 268,
#  'Forever 21': 263,
#  "America's Best Contacts & Eyeglasses": 262,
#  "Papa Murphy's": 260,
#  'Torrid': 259,
#  'White House Black Market': 259,
#  'Zumiez': 258,
#  'Outback Steakhouse': 256,
#  'Big Lots': 255,
#  'Charleys Cheesesteaks': 253,
#  'Walmart Vision & Glasses': 249,
#  'Potbelly Sandwich Shop': 249,
#  'Einstein Bros. Bagels': 248,
#  'JCPenney': 246,
#  'Burlington': 244,
#  'Visionworks': 243,
#  'MrBeast Burger': 243,
#  'Sleep Number': 241,
#  'Hobby Lobby': 241,
#  'Red Robin Gourmet Burgers and Brews': 238,
#  'Lids': 237,
#  'Wawa': 234,
#  'JOANN Fabric and Crafts': 231,
#  'LOFT': 231,
#  'SmartStyle': 227,
#  'Journeys': 226,
#  "Chico's": 226,
#  "Moe's Southwest Grill": 226,
#  'MOD Pizza': 223,
#  'MetroPCS': 221,
#  'Cracker Barrel Old Country Store': 217,
#  'Home Goods': 216,
#  'Office Depot': 215,
#  'Red Lobster': 215,
#  'In-N-Out Burger': 213,
#  'Safeway Pharmacy': 211,
#  'Del Taco': 211,
#  'Noodles & Company': 211,
#  "Hardee's": 209,
#  'El Pollo Loco': 206,
#  "Carter's Babies & Kids": 205,
#  'ampm': 204,
#  'Target Optical': 204,
#  'Express': 203,
#  'STARBUCKS COFFEE': 203,
#  'Spectrum': 202,
#  'DSW Designer Shoe Warehouse': 202,
#  "The Children's Place": 201,
#  'Walmart': 200,
#  'LongHorn Steakhouse': 198,
#  "Culver's": 197,
#  'Blaze Pizza': 194,
#  'The Habit Burger Grill': 194,
#  "Wetzel's Pretzels": 192,
#  'Cinnabon': 191,
#  'Harbor Freight Tools': 189,
#  'Kroger': 189,
#  'Waffle House': 187,
#  'Michael Kors': 187,
#  'Dutch Bros Coffee': 186,
#  'Nothing Bundt Cakes': 184,
#  'MAC Cosmetics': 183,
#  "Zaxby's Chicken Fingers & Buffalo Wings": 182,
#  "See's Candies": 182,
#  'Texas Roadhouse': 182,
#  'Metro by T-Mobile': 181,
#  "Leslie's": 180,
#  'Finish Line': 176,
#  'Zales Jewelers': 175,
#  'Shell': 175,
#  'Banana Republic': 174,
#  'Boost  Mobile': 174,
#  'MyEyeDr': 174,
#  'Windsor': 173,
#  'Aéropostale': 173,
#  "Peet's Coffee": 172,
#  'Whataburger': 172,
#  'First Watch': 171,
#  'Verizon Authorized Retailer - Cellular Sales': 171,
#  'Round Table Pizza': 167,
#  'Kung Fu Tea': 167,
#  'Chevron': 166,
#  "Sam's Club": 165,
#  'Cellairis': 163,
#  'Gap': 162,
#  'Hollister': 162,
#  'Coach': 162,
#  'Sheetz': 161,
#  'Build-A-Bear Workshop': 161,
#  "Raising Cane's Chicken Fingers": 161,
#  'Jos. A. Bank': 160,
#  'CubeSmart Self Storage': 159,
#  'sweetgreen': 157,
#  'Anthropologie': 157,
#  "Claire's": 157,
#  'Stop & Shop': 156,
#  'Walmart Garden Center': 156,
#  'Buckle': 155,
#  'Barnes & Noble': 155,
#  'Little Caesars': 155,
#  'Lane Bryant': 154,
#  'Insomnia Cookies': 154,
#  "Spencer's": 154,
#  'Soma': 152,
#  'Pearle Vision': 151,
#  'Big 5 Sporting Goods': 151,
#  'Warby Parker': 149,
#  'Chuck E. Cheese': 149,
#  'Walmart Photo Center': 148,
#  'Hair Cuttery': 148,
#  "P.F. Chang's": 148,
#  'Party City': 146,
#  'Spirit Halloween': 146,
#  'Rack Room Shoes': 145,
#  'Publix': 145,
#  'Cava': 145,
#  'uBreakiFix by Asurion': 144,
#  'Swarovski': 143,
#  'Sprouts Farmers Market': 142,
#  'Family Dollar': 140,
#  'Barnes & Noble Booksellers': 139,
#  'Athleta': 139,
#  "Marco's Pizza": 138,
#  'Benefit Brow Bar at Ulta': 137,
#  'Urban Outfitters': 136,
#  'QuikTrip': 136,
#  'Nordstrom Rack': 136,
#  'TGI Fridays': 136,
#  "Dickey's Barbecue Pit": 135,
#  'Häagen-Dazs': 134,
#  'Ben & Jerry’s': 133,
#  'Gap Factory': 133,
#  "BJ's Restaurant & Brewhouse": 133,
#  'Goodwill': 133,
#  "McAlister's Deli": 132,
#  'Piercing Pagoda': 132,
#  'Caribou Coffee': 131,
#  'The Cheesecake Factory': 131,
#  'Tuesday Morning': 130,
#  "Casey's": 129,
#  "Champ's Sports": 128,
#  'The Coffee Bean & Tea Leaf': 127,
#  'Tim Hortons': 127,
#  'Talbots': 125,
#  'Nike Factory Store': 125,
#  'Banana Republic Factory Store': 125,
#  'Steak ’n Shake': 125,
#  'Batteries Plus Bulbs': 124,
#  'Hand & Stone Massage and Facial Spa': 124,
#  'Fantastic Sams Hair Salons': 124,
#  "Aaron's": 124,
#  'Bluemercury': 123,
#  'Ashley HomeStore': 123,
#  'Tillys': 123,
#  'Pottery Barn': 123,
#  'Yogurtland': 123,
#  'Total Wine & More': 122,
#  'J.Crew': 121,
#  'Abercrombie & Fitch': 121,
#  'World Market': 120,
#  "David's Bridal": 120,
#  'Rocky Mountain Chocolate Factory': 120,
#  'Krispy Kreme': 120,
#  'Duane Reade': 119,
#  'Shoe Palace': 115,
#  'Bob Evans': 115,
#  'Grocery Outlet Bargain Market': 113,
#  'Levi’s Outlet Store': 113,
#  'Pandora': 113,
#  'Williams-Sonoma': 113,
#  'Sbarro': 112,
#  'Guitar Center': 112,
#  'Lucky Brand': 111,
#  'California Pizza Kitchen': 110,
#  'Verizon Authorized Retailer, TCC': 110,
#  'STARBUCKS': 110,
#  'Maurices': 110,
#  "Freddy's Frozen Custard & Steakburgers": 109,
#  'J.Jill': 109,
#  'BevMo!': 109,
#  '99 Cents Only Stores': 109,
#  'Things Remembered': 108,
#  'Boot Barn': 108,
#  'Great American Cookies': 106,
#  'Rue 21': 106,
#  'L&L Hawaiian Barbecue': 105,
#  'Hooters': 105,
#  'Sephora': 104,
#  'Pressed': 104,
#  'SKECHERS Factory Outlet': 104,
#  "Long John Silver's": 104,
#  'Costco': 103,
#  'Cost Cutters': 103,
#  'Albertsons': 103,
#  'REI': 102,
#  'Madewell': 102,
#  'Verizon Authorized Retailer - Wireless Zone': 101,
#  'The Burger Den': 100,
#  "Mountain Mike's Pizza": 100,
#  'Mattress Warehouse': 100,
#  'Costco Wholesale': 99,
#  'DXL': 99,
#  'Free People': 99,
#  "Auntie Anne's Pretzels": 99,
#  'La-Z-Boy Furniture Galleries': 98,
#  'Helzberg Diamonds': 97,
#  'Hy-Vee': 96,
#  'Menchies Frozen Yogurt': 96,
#  'Sears Optical': 96,
#  'PacSun': 96,
#  'Ann Taylor': 96,
#  'J.Crew Factory': 95,
#  'Subway Restaurants': 95,
#  'Gong Cha': 95,
#  'Dairy Queen': 95,
#  "L'Occitane": 94,
#  'Benefit Cosmetics BrowBar': 94,
#  'Smashburger': 93,
#  'Tractor Supply': 93,
#  'Lovesac': 93,
#  'Meijer': 93,
#  'Shake Shack': 93,
#  'Lululemon Athletica': 92,
#  'Famous Footwear Outlet': 92,
#  'Nekter Juice Bar': 91,
#  'Vons': 91,
#  "Dillard's": 90,
#  'The Container Store': 90,
#  'kate spade new york outlet': 90,
#  'Sarku Japan': 89,
#  'Cumberland Farms': 88,
#  'Columbia Factory Store': 88,
#  'Golden Corral Buffet & Grill': 88,
#  'A&W Restaurant': 88,
#  'Old Navy Outlet': 87,
#  'Ralphs': 87,
#  "TOGO'S Sandwiches": 87,
#  'Honey Baked Ham Company': 86,
#  'Asurion Tech Repair & Solutions': 85,
#  'Wienerschnitzel': 85,
#  'JCPenney Optical': 85,
#  'LOFT Outlet': 84,
#  'The Body Shop': 84,
#  'Yankee Candle': 83,
#  "Rubio's Coastal Grill": 83,
#  "Plato's Closet": 83,
#  'Walmart Neighborhood Market': 83,
#  "Stewart's Shops": 83,
#  'Dairy Queen Ltd Brazier': 83,
#  "Bruegger's Bagels": 82,
#  "Ruth's Chris Steak House": 82,
#  "Kirkland's": 82,
#  'Regis Salon': 82,
#  'Brooks Brothers Factory Outlet': 82,
#  "Schlotzsky's": 82,
#  "Captain D's": 81,
#  'Paper Source': 81,
#  'Au Bon Pain': 81,
#  'Ruby Tuesday': 81,
#  'BoxLunch': 80,
#  'Kum & Go': 80,
#  "Jason's Deli": 80,
#  'Boston Market': 79,
#  'Playa Bowls': 79,
#  'Aldo': 79,
#  'WaBa Grill': 79,
#  'Paris Baguette': 78,
#  'Eddie Bauer': 78,
#  'Officemax': 78,
#  "Jet's Pizza": 78,
#  'Lush': 77,
#  "Amy's Hallmark Shop": 77,
#  "OshKosh B'gosh": 77,
#  "Francesca's Collections": 76,
#  "Daniel's Jewelers": 76,
#  'Wing Squad': 76,
#  "Macy's Backstage": 76,
#  'Johnny Rockets': 76,
#  'Shoe Carnival': 76,
#  'Krispy Krunchy Chicken': 76,
#  'Mobil': 75,
#  'Kendra Scott': 75,
#  "BJ's Wholesale Club": 75,
#  "Floyd's 99 Barbershop": 75,
#  'White Castle': 75,
#  'Ethan Allen': 75,
#  'The Salvation Army Family Store & Donation Center': 75,
#  'Nordstrom': 75,
#  'Checkers': 74,
#  'Exxon': 74,
#  'At Home': 74,
#  'The SALON by InStyle inside JCPenney': 73,
#  'Quiznos': 73,
#  "Rita's Italian Ice": 73,
#  'China Wok': 73,
#  'Yard House': 73,
#  "Claire's Boutique": 73,
#  'West Marine': 73,
#  'Calvin Klein': 73,
#  'Nordstrom Ebar Artisan Coffee': 73,
#  'Regal Nails': 73,
#  'Bojangles': 72,
#  'Food Lion': 72,
#  "Carrabba's Italian Grill": 72,
#  'Which Wich': 72,
#  "Cohen's Fashion Optical": 72,
#  'Perfumania': 72,
#  'RaceTrac': 72,
#  'Smart & Final Extra!': 71,
#  'Brooks Brothers': 71,
#  'Publix Super Markets': 71,
#  'Sharetea': 71,
#  'The Halal Guys': 70,
#  'Zara': 70,
#  'Dollar Tree Stores': 70,
#  'Best Buy': 69,
#  'Meijer Pharmacy': 69,
#  'Oakley': 69,
#  'Music & Arts': 69,
#  "Chico's Off The Rack": 68,
#  "Dunkin' Donuts": 68,
#  'lululemon athletica': 68,
#  "Taco John's": 68,
#  'Tory Burch': 68,
#  'Marble Slab Creamery': 67,
#  "Capriotti's Sandwich Shop": 67,
#  'Giant Food': 67,
#  'Pro Nails': 67,
#  'Eyemart Express': 67,
#  'Cafe Rio Mexican Grill': 66,
#  'Saks OFF 5TH': 66,
#  'Vera Bradley': 66,
#  'Red Wing Shoe Store': 66,
#  'Harris Teeter': 66,
#  'Guess': 65,
#  'Vitamin World': 65,
#  'Fine Wine & Good Spirits': 65,
#  'Fred Meyer': 65,
#  'Bonchon': 65,
#  'Tommy Bahama': 65,
#  "Church's Chicken": 65,
#  'Clarks': 65,
#  'MasterCuts': 64,
#  "Ike's Love & Sandwiches": 64,
#  'Cash America Pawn': 64,
#  'Floor & Decor': 64,
#  'Tiffany & Co.': 64,
#  'Cook Out': 64,
#  'Fabletics': 63,
#  'The Cosmetics Company Store': 63,
#  'west elm': 63,
#  'Aldo Shoes': 63,
#  'UScellular': 63,
#  "Francesca's": 63,
#  'School of Rock': 63,
#  'Color Me Mine': 62,
#  'Tommy Hilfiger': 62,
#  'Aveda Store': 62,
#  "Cheddar's Scratch Kitchen": 62,
#  'sweetFrog Premium Frozen Yogurt': 61,
#  'Star Nails': 61,
#  'Eddie Bauer Outlet': 61,
#  'Under Armour Factory House': 61,
#  'Rent-A-Center': 61,
#  "IT'SUGAR": 60,
#  "Claire's Boutiques": 60,
#  "Dave's Hot Chicken": 60,
#  "Kid's Foot Locker": 60,
#  'UNTUCKit': 60,
#  'BurgerFi': 60,
#  'Bellhop Moving': 59,
#  'Bonefish Grill': 59,
#  "Jeni's Splendid Ice Creams": 59,
#  'Virginia ABC Store': 59,
#  'Yankee Candle Company': 58,
#  'The Bistro': 58,
#  'Academy Sports + Outdoors': 58,
#  'Arhaus': 58,
#  'IKEA': 58,
#  'Fancy Nails': 58,
#  'Lovely Nails': 58,
#  'Ann Taylor Factory Store': 57,
#  "Kiehl's Since 1851": 57,
#  'Janie and Jack': 57,
#  'The Capital Grille': 57,
#  'Perkins Restaurant & Bakery': 57,
#  'Salata': 57,
#  'Phenix Salon Suites': 56,
#  'Batteries Plus': 56,
#  'Hy-Vee Fast & Fresh': 56,
#  'Cosmo Prof': 56,
#  'Cotton On': 56,
#  "Guy Fieri's Flavortown Kitchen": 56,
#  'Costco Food Court': 56,
#  'Maverik': 55,
#  'Crate & Barrel': 55,
#  'Vineyard Vines': 55,
#  "Altar'd State": 55,
#  'Ferguson Plumbing Supply': 55,
#  'Top Nails': 55,
#  'SalonCentric': 55,
#  'Fantastic Sams': 55,
#  'Tumi': 55,
#  'China King': 55,
#  "Ollie's Bargain Outlet": 55,
#  'Juice Press': 54,
#  'Pretzelmaker': 54,
#  'Cycle Gear': 54,
#  'Verizon Wireless': 54,
#  "LensCrafters At Macy's": 54,
#  'Chopt Creative Salad Co.': 54,
#  "Chuy's": 54,
#  'Fye': 54,
#  "Mariah's Cookies": 54,
#  'Tyga Bites': 54,
#  'Natural Grocers': 53,
#  'Philz Coffee': 53,
#  'Sola Salon Studios': 53,
#  'Samsonite Outlet': 53,
#  'Kelly-Moore Paints': 53,
#  'ReadyRefresh': 53,
#  'Aesop': 53,
#  'Cole Haan': 53,
#  'Robeks Fresh Juices & Smoothies': 53,
#  'Ferguson Bath, Kitchen & Lighting Gallery': 53,
#  'Menards': 53,
#  'Happy Lemon': 52,
#  'Steve Madden': 52,
#  'W XYZ Bar': 52,
#  'Dunn-Edwards Paints': 52,
#  'Pret A Manger': 52,
#  'Polo Ralph Lauren': 52,
#  'Everything But Water': 52,
#  'Fragrance Outlet': 52,
#  'Dairy Queen Store': 52,
#  'Winn-Dixie': 52,
#  'Gyu-Kaku Japanese BBQ': 51,
#  'Go! Calendars, Toys & Games': 51,
#  'Champs': 51,
#  'Daiso Japan': 51,
#  'Ono Hawaiian BBQ': 51,
#  'JC Penney Salon': 51,
#  "Love's Travel Stop": 51,
#  'Valero': 51,
#  'SKECHERS Warehouse Outlet': 51,
#  'Oakley Vault': 50,
#  "dd's DISCOUNTS": 50,
#  'The Dinner Detective': 50,
#  'Play It Again Sports': 50,
#  'RadioShack': 50,
#  'Le Pain Quotidien': 50,
#  'kate spade new york': 50,
#  'Hugo Boss': 50,
#  'FedEx Ship Center': 50,
#  'Burberry': 50,
#  'Chicken Salad Chick': 50,
#  'Donatos Pizza': 50,
#  'Guitar Center Lessons': 50,
#  'Lidl': 50,
#  'Fogo de Chão Brazilian Steakhouse': 49,
#  'Benihana': 49,
#  'Jared Galleria of Jewelry': 49,
#  'China Garden': 49,
#  'PUMA': 49,
#  'Nautica': 49,
#  "Bob's Discount Furniture and Mattress Store": 49,
#  "Scooter's Coffee": 49,
#  'Wegmans': 49,
#  "Morton's The Steakhouse": 48,
#  'Pita Pit': 48,
#  "The Children's Place Outlet": 48,
#  'Just Salad': 48,
#  'Cato': 48,
#  'Mission BBQ': 48,
#  'American Deli': 48,
#  '99 Restaurants': 47,
#  'Queen Nails': 47,
#  'Capital One Café': 47,
#  'Lee Nails': 47,
#  "Sportsman's Warehouse": 47,
#  'Save A Lot': 47,
#  'Giant': 47,
#  'Family Dollar Store': 47,
#  'Happy Nails': 47,
#  'My Eyelab': 47,
#  'The Fresh Market': 47,
#  'Planet Smoothie': 47,
#  'Shiekh Shoes': 46,
#  'Shoe Dept. Encore': 46,
#  'JOE & THE JUICE': 46,
#  'Blo Blow Dry Bar': 46,
#  'Meijer Express Gas Station': 46,
#  'Port of Subs': 46,
#  'Once Upon A Child': 46,
#  "Fazoli's": 46,
#  'Mendocino Farms': 45,
#  'Indochino': 45,
#  'Pepper Palace': 45,
#  "Torchy's Tacos": 45,
#  'Fleet Feet': 45,
#  'Lululemon': 45,
#  'Cricket Wireless Authorized Retailer': 45,
#  'Pei Wei Asian Kitchen': 45,
#  'Raising Canes': 45,
#  "O'Charley's Restaurant & Bar": 45,
#  'Villa Fresh Italian Kitchen': 45,
#  'SKECHERS Retail': 45,
#  'For Eyes': 45,
#  'King Soopers': 45,
#  'Homegoods': 45,
#  'Food 4 Less': 45,
#  'Saladworks': 44,
#  'Aritzia': 44,
#  'Massage Heights': 44,
#  'Don Roberto Jewelers': 44,
#  'Brighton': 44,
#  'Fleming’s Prime Steakhouse & Wine Bar': 44,
#  'Freshii': 44,
#  'Ledo Pizza': 44,
#  'Hibbett Sports': 44,
#  'Zales': 44,
#  'Eileen Fisher': 44,
#  'Jewel-Osco': 44,
#  'LA Nails': 44,
#  'True Religion': 44,
#  'Orvis': 43,
#  'Crystal Springs Water': 43,
#  'Angel Nails': 43,
#  'Bonobos': 43,
#  'Wings Out': 43,
#  "Claire's Accessories": 43,
#  'Popeye’s': 43,
#  'H-E-B': 43,
#  'Flame Broiler': 43,
#  'Pinkberry': 43,
#  'Raymour & Flanigan Furniture and Mattress Store': 43,
#  'Yoshinoya': 43,
#  'Fashion Nails': 43,
#  "Famous Dave's Bar-B-Que": 43,
#  'Kilwins': 43,
#  'Tj Maxx': 43,
#  'Goodwill Southern California Retail Store & Donation Center': 43,
#  "Logan's Roadhouse": 43,
#  'Cicis Pizza': 42,
#  'Half Price Books': 42,
#  'Jockey Outlet': 42,
#  'Baja Fresh': 42,
#  'Royal Farms': 42,
#  'Cvs Pharmacy': 42,
#  'Stanton Optical': 42,
#  "BJ's Optical": 42,
#  'Glamour Nails': 42,
#  'Johnny Was': 42,
#  'Allen Edmonds': 42,
#  'Teriyaki Madness': 42,
#  'Polo Ralph Lauren Factory Store': 42,
#  'Modern Nails': 42,
#  "Dunham's Sports": 42,
#  'Armani Exchange': 42,
#  'Vons Pharmacy': 42,
#  'la Madeleine': 42,
#  'Regal Nails Salon & Spa': 42,
#  "Fuzzy's Taco Shop": 41,
#  'Penn Station East Coast Subs': 41,
#  'Cosmoprof': 41,
#  'Buca di Beppo Italian Restaurant': 41,
#  'Tous Les Jours': 41,
#  'Miniso': 41,
#  'Krystal': 41,
#  'Cache': 41,
#  'Stater Bros. Markets': 41,
#  'Merle Norman Cosmetics': 41,
#  'The Salvation Army Thrift Store & Donation Center': 41,
#  'BP': 41,
#  'Lilly Pulitzer': 40,
#  'Elegant Nails': 40,
#  'True Food Kitchen': 40,
#  'Family Dollar Stores': 40,
#  "Friendly's": 40,
#  'Relax The Back': 40,
#  'Safeguard Self Storage': 40,
#  'Gymboree': 40,
#  'ACME Markets': 40,
#  'Mattress One': 40,
#  'Halal Cart': 40,
#  'Le Creuset Outlet Store': 40,
#  'lululemon': 40,
#  'Fossil Store': 40,
#  'The Melting Pot': 40,
#  'Blick Art Materials': 40,
#  'Amazon Fresh': 40,
#  '5.11 Tactical': 40,
#  'Pilot Travel Center': 40,
#  'Wahlburgers @ Hy-Vee': 39,
#  'China Max': 39,
#  'DQ / Orange Julius': 39,
#  "Rosati's Pizza": 39,
#  'Metro Pcs': 39,
#  'Man vs Fries': 39,
#  'Another Broken Egg Cafe': 39,
#  'Aeropostale': 39,
#  'Perfect Nails': 39,
#  'Nathans Famous': 39,
#  'Dippin’ Dots': 39,
#  'Johnston & Murphy': 39,
#  'Books-A-Million': 39,
#  'Buy Buy Baby': 39,
#  'The Flame Broiler': 39,
#  'China Express': 39,
#  'Pokeworks': 38,
#  'ASICS Outlet': 38,
#  'Sunoco': 38,
#  "Hungry Howie's Pizza": 38,
#  'Rainbow': 38,
#  'Garage': 38,
#  'HairMasters': 38,
#  'New Balance Factory Store': 38,
#  'Carter’s': 38,
#  'Taco Time': 38,
#  'Corner Bakery': 38,
#  "Rally's": 38,
#  'Sur La Table': 38,
#  'Farmer Boys': 38,
#  'L.L. Bean': 37,
#  'Movado Company Store': 37,
#  'OfficeMax': 37,
#  "Raley's": 37,
#  'Peloton': 37,
#  "See's Candies Seasonal Pop Up Shop": 37,
#  'Walmart Bakery': 37,
#  'Ocean State Job Lot': 37,
#  'Twin Peaks': 37,
#  'Solstice Sunglasses': 37,
#  'Taco Cabana': 37,
#  'Luxury Nails': 37,
#  'The Original Pancake House': 37,
#  'Adidas': 37,
#  'Grocery Outlet': 37,
#  'Lucky': 37,
#  'Eyeglass World': 37,
#  'Price Chopper': 37,
#  'Juice It Up!': 37,
#  'ALDO': 36,
#  'Earthbound Trading Company': 36,
#  'Pollo Tropical': 36,
#  'Icing': 36,
#  'Marine Layer': 36,
#  'Jamba Juice': 36,
#  'Gucci': 36,
#  'Aerie': 36,
#  'Bluestone Lane': 36,
#  "Tiff's Treats": 36,
#  "Roosters Men's Grooming Center": 36,
#  'Sunglass Hut International': 36,
#  'Village Inn': 36,
#  'Interstate All Battery Center': 36,
#  'Pizza Factory': 36,
#  'Giant Food Stores': 36,
#  'Savers': 36,
#  'Saltgrass Steak House': 36,
#  'SEE': 35,
#  'UNIQLO': 35,
#  'Bartell Drugs': 35,
#  'Re-Bath': 35,
#  'Wow Bao': 35,
#  'Yum Yum Donuts': 35,
#  'Ruby Thai Kitchen': 35,
#  'Cartridge World': 35,
#  'Cinnaholic': 35,
#  "Rita's Italian Ice & Frozen Custard": 35,
#  'Golf Galaxy': 35,
#  'Nail Spa': 35,
#  'Hudson News': 35,
#  'Kevin Jewelers': 35,
#  'Clarkson Eyecare': 35,
#  'DQ Grill & Chill Restaurant': 35,
#  'Fossil Outlet Store': 35,
#  'Albertsons Pharmacy': 35,
#  'Costco Optical': 35,
#  'Buff City Soap': 35,
#  'WinCo Foods': 35,
#  'Shoe Dept.': 35,
#  "Spec's Wines, Spirits & Finer Foods": 35,
#  'Footaction USA': 34,
#  'Costa Vida': 34,
#  'Snooze, an A.M. Eatery': 34,
#  'Evereve': 34,
#  'Jollibee': 34,
#  "Noah's NY Bagels": 34,
#  'iFixandRepair': 34,
#  'Lolli and Pops': 34,
#  "It's Just Wings": 34,
#  "Nando's Peri-Peri": 34,
#  'Vitality Bowls': 34,
#  'California Fish Grill': 34,
#  "Bruster's Real Ice Cream": 34,
#  'Fred Meyer Jewelers': 34,
#  'Hong Kong Express': 34,
#  'Wayback Burgers': 34,
#  'Topgolf': 34,
#  'Ace Hardware': 34,
#  'Longs Drugs': 34,
#  "Shaw's": 34,
#  'Pretty Nails': 34,
#  'Great Wraps': 33,
#  'Nail Studio': 33,
#  'Reebok Factory Direct Store': 33,
#  'Rockler Woodworking & Hardware': 33,
#  'Soothe': 33,
#  'Seasons 52': 33,
#  'Giant Eagle': 33,
#  "Maggiano's Little Italy": 33,
#  'Blank Street Coffee': 33,
#  'Johnston & Murphy Shop': 33,
#  'Verizon Authorized Retailer - Russell Cellular': 33,
#  'Off Broadway Shoes': 33,
#  'WFM Coffee Bar': 33,
#  'Black Rock Coffee Bar': 33,
#  'Everytable': 32,
#  'Ten Thousand Villages': 32,
#  'Walmart Vision Center': 32,
#  'Brookstone': 32,
#  'Wings & Things': 32,
#  'Red Mango': 32,
#  'Goodwill Store': 32,
#  'Rocket Fizz': 32,
#  'Villa Italian Kitchen': 32,
#  "Victoria's Secret PINK": 32,
#  'Quickly': 32,
#  'Dog Haus': 32,
#  'Islands Restaurant': 32,
#  'Gregorys Coffee': 32,
#  'Lazy Dog Restaurant & Bar': 32,
#  'Salvatore Ferragamo': 32,
#  'Smart & Final': 32,
#  "SEPHORA at Kohl's": 32,
#  'Road Runner Sports': 32,
#  'The Old Spaghetti Factory': 32,
#  'Luxury Nails & Spa': 32,
#  'Elite Nails': 32,
#  'Kitchen Collection': 32,
#  'The Tile Shop': 31,
#  'Villa Pizza': 31,
#  'Taco Time NW': 31,
#  "Jolene's Wings + Beer": 31,
#  "Miller's Ale House": 31,
#  'Saint Laurent': 31,
#  'Ben Bridge Jeweler': 31,
#  'Express Factory Outlet': 31,
#  'Neiman Marcus': 31,
#  'Slim Chickens': 31,
#  'Huddle House': 31,
#  "Grimaldi's Pizzeria": 31,
#  'Lush Cosmetics': 31,
#  'Bassett Furniture': 31,
#  "Shari's Cafe and Pies": 31,
#  'Crocs': 31,
#  "Mimi's Cafe": 31,
#  'Kroger Pharmacy': 31,
#  'Holiday Hair': 31,
#  'California Nails': 31,
#  "Sunglass Hut at Macy's": 30,
#  'Tijuana Flats': 30,
#  'Denver Mattress': 30,
#  'Taco Del Mar': 30,
#  'Pottery Barn Kids': 30,
#  'Brandy Melville': 30,
#  'Lego Store': 30,
#  "Fatburger & Buffalo's Express": 30,
#  'Hollywood Nails': 30,
#  'US Nails': 30,
#  "Newk's Eatery": 30,
#  'Krispy Rice': 30,
#  'Red Wing Shoes': 30,
#  'AllSaints': 30,
#  'Skyline Chili': 30,
#  'Brio Italian Grille': 30,
#  'Stuart Weitzman': 30,
#  'Best Nails': 30,
#  'Camping World': 30,
#  'Calico': 30,
#  'Duck Donuts': 30,
#  'Godfathers Pizza': 30,
#  'Sherwin-Williams Commercial Paint Store': 30,
#  'La Michoacana': 30,
#  'The Paper Store': 30,
#  'Chicken Express': 30,
#  "US Foods CHEF'STORE": 29,
#  'DaVi Nails': 29,
#  'Shipley Do-Nuts': 29,
#  'Blimpie': 29,
#  'Earthbar': 29,
#  'Saks Fifth Avenue': 29,
#  'Cox Store': 29,
#  'Surf City Squeeze': 29,
#  'China Buffet': 29,
#  'Corner Bakery Cafe': 29,
#  'Your Wireless': 29,
#  'Magic Nails': 29,
#  'Ortho Mattress': 29,
#  'Starbucks Pickup': 29,
#  'Motherhood Maternity': 29,
#  'Papaya Clothing': 29,
#  'China Star': 29,
#  'Pandora Jewelry': 29,
#  'Pardon My Cheesesteak': 29,
#  'China House': 29,
#  'Veggie Grill': 29,
#  'Dominos': 29,
#  'Fine Wine & Good Spirits - Premium Collection': 29,
#  'Duluth Trading Company': 29,
#  'Emerald City Smoothie': 29,
#  'Pizza Ranch': 29,
#  'Learning Express Toys': 29,
#  'Pizza Guys': 29,
#  'City Nails': 29,
#  'KWIK TRIP': 29,
#  'Ewing Irrigation & Landscape Supply': 29,
#  'Portrait Innovations': 29,
#  'Old Chicago Pizza + Taproom': 29,
#  'Tractor Supply Company': 29,
#  'Goodwill Industries': 29,
#  "Conn's HomePlus": 29,
#  "Gabe's": 29,
#  "Icing by Claire's": 28,
#  'QFC': 28,
#  'Pollo Campero': 28,
#  'Converse': 28,
#  'Design Within Reach': 28,
#  'BIBIBOP Asian Grill': 28,
#  'Save Mart': 28,
#  'The Shop': 28,
#  'Potato Corner': 28,
#  'BIGGBY COFFEE': 28,
#  "Bojangles' Famous Chicken 'n Biscuits": 28,
#  'IKEA Restaurant': 28,
#  'Q Nails': 28,
#  'Bento Sushi': 28,
#  'Luna Grill': 28,
#  'ABC Stores': 28,
#  'Ralph Lauren': 28,
#  'Belk': 28,
#  "Menchie's": 28,
#  'Havertys Furniture': 28,
#  'Value City Furniture': 28,
#  'Nutrishop': 28,
#  'Natural Nails': 28,
#  'Blue Bottle Coffee': 27,
#  'Pacsun': 27,
#  'Cozymeal': 27,
#  'New China': 27,
#  'Wahlburgers': 27,
#  'Hermès': 27,
#  "PJ's Coffee": 27,
#  'Cheba Hut Toasted Subs': 27,
#  'pOpshelf': 27,
#  'Pinch A Penny': 27,
#  'Golden Nails': 27,
#  'Zales Outlet': 27,
#  'Bloomingdale’s ': 27,
#  'Carvel': 27,
#  'Charleys Cheesesteaks and Wings': 27,
#  "Winchell's Donuts": 27,
#  'Kura Revolving Sushi Bar': 27,
#  'Jimmy Choo': 27,
#  'Tutti Frutti': 27,
#  'David Yurman': 27,
#  'Firebirds Wood Fired Grill': 27,
#  'Lacoste': 27,
#  'K&G Fashion Superstore': 27,
#  'Freebirds World Burrito': 27,
#  'P.C. Richard & Son': 27,
#  'Dollar Tree Store': 27,
#  '7-Eleven Hawaii': 27,
#  'Davi Nails': 27,
#  'China One': 26,
#  'WSS': 26,
#  'Tender Greens': 26,
#  "Murphy's Deli": 26,
#  'Roche Bobois': 26,
#  'Smokey Bones ': 26,
#  'Hook & Reel Cajun Seafood & Bar': 26,
#  'PrimoHoagies': 26,
#  'Mac  Cosmetics': 26,
#  'Roti': 26,
#  'Belk Department Store': 26,
#  'Hard Rock Cafe': 26,
#  'The Human Bean': 26,
#  'Velvet Taco': 26,
#  'Hong Kong Restaurant': 26,
#  'Fatburger': 26,
#  'Purple Mattress Showroom': 26,
#  'Sur La Table Cooking Class': 26,
#  'Anthony Vince Nail Spa': 26,
#  'Uno Pizzeria & Grill': 26,
#  'Newbury Comics': 26,
#  'Lakeshore Learning Store': 26,
#  '7 For All Mankind': 26,
#  'Zoup!': 26,
#  'Soft Surroundings': 26,
#  'El Torito': 26,
#  'Harris Teeter Pharmacy': 26,
#  'Fantastic Sams Cut & Color': 26,
#  ...}

# %%
size = len(list(processed_places_near_ev.keys())) // 3
part_1 = {}
part_2 = {}
part_3 = {}
for key in list(processed_places_near_ev.keys())[:size]:
    part_1[key] = processed_places_near_ev[key]
    
for key in list(processed_places_near_ev.keys())[size:-size]:
    part_2[key] = processed_places_near_ev[key]
for key in list(processed_places_near_ev.keys())[-size:]:
    part_3[key] = processed_places_near_ev[key]

# %%
import csv

with open("part_1.csv", "w") as f:
    f.write("name, near_x_stations,\r\n")
    for key in part_1.keys():
        f.write("{},{},\r\n".format(str(key).replace(",", ""), part_1[key]))
        
with open("part_2.csv", "w") as f:
    f.write("name, near_x_stations,\r\n")
    for key in part_2.keys():
        f.write("{},{},\r\n".format(str(key).replace(",", ""), part_2[key]))    
    
with open("part_3.csv", "w") as f:
    f.write("name, near_x_stations,\r\n")
    for key in part_3.keys():
        f.write("{},{},\r\n".format(str(key).replace(",", ""), part_3[key]))

# %%
just_websites = []
all_info = []
for key in processed_places_near_ev:
    if processed_places_near_ev[key] >= 30:
        just_websites.append(key.replace(",", "").replace(" ", "").replace("/", ""))
    else:
        all_info.append(key.replace(",", "").replace(" ", "").replace("/", ""))

# %%
len(just_websites)
# Out:
# 2072

# %%
#len(part_3.keys())
# Out:
# 387121

# %%
len(all_info)
# Out:
# 1159291

# %%
import csv
with open('all_info.csv', 'w') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerow(all_info)

# %%
import csv
with open('just_websites.csv', 'w') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerow(just_websites)
